# %%
import pandas as pd
import json

# %%
eeg = pd.read_csv("/projectnb/vkolagrp/ketanss/adrdfm-2/brainlat/output_summaries/brainlat_summaries_clean.csv")

# %%
eeg.columns
# Out:
# Index(['Diagnosis', 'visit_summary_prompt', 'visit_summary'], dtype='object')

# %%
eeg[~eeg['MRI Report'].isna()]

# %%
eeg['Diagnosis'].value_counts()
# Out:
# Diagnosis
# Alzheimer's disease                           250
# Healthy                                       191
# Behavioral variant frontotemporal dementia    131
# Parkinson's disease                            36
# Multiple sclerosis                             25
# Name: count, dtype: int64

# %%
json.loads(eeg.iloc[0]['input_json'])
# Out:
# {'Metadata': '{"Sex": 1, "Age": 81, "Years of education": 12, "Laterality": 1.0, "Total score of MoCa (0\\u201330)": 9.0, "MoCa visuospatial assessment (0\\u20135)": 3.0, "MoCa recognition assessment (0\\u20133)": 1.0, "MoCa attention assessment (0\\u20136)": 4.0, "MoCa language assessment (0\\u20133)": 0.0, "MoCa abstraction assessment (0\\u20132)": 0.0, "MoCa memory assessment (0\\u20135)": 0.0, "MoCa orientation assessment (0\\u20136)": 1.0, "Total score of INECO Frontal Screening (0\\u201330)": 10.0, "Motor Programming INECO Frontal Screening subset (0\\u20133)": 0.0, "Conflicting Instructions INECO Frontal Screening subset (0\\u20133)": 3.0, "Go/No Go INECO Frontal Screening subset (0\\u20133)": 0.0, "Backward Digit Span INECO Frontal Screening subset (0\\u20136)": 3.0, "Verbal Working Memory INECO Frontal Screening subset (0\\u20132)": 0.0, "Spatial Working Memory INECO Frontal Screening subset (0\\u20134)": 1.0, "Abstraction Capacity INECO Frontal Screening subset (0\\u20133)"
# ...

# %%
print(eeg.iloc[130]['visit_summary'])
# Out:
# The patient is an 81-year-old right-handed female with 4 years of education. Neuropsychological evaluation using the Montreal Cognitive Assessment (MoCa) revealed a total score of 15 out of 30, which is below the typical cutoff for normal cognitive function. The visuospatial assessment component scored 3 out of 5, indicating some impairment in this domain. Recognition assessment was within the average range, scoring 3 out of 3. The attention assessment yielded a score of 4 out of 6, suggesting mild difficulty with attention. Language assessment was 2 out of 3, pointing to some challenges in language tasks. The abstraction assessment scored 2 out of 2, indicating intact performance in this area. Memory assessment was notably impaired, with a score of 0 out of 5, and orientation assessment scored 1 out of 6, reflecting significant difficulty with orientation.
#
# ...
