# %%
import pandas as pd

# %%
# ans_path = "/projectnb/vkolagrp/bellitti/adrd-foundation-model/adrd_simplified_evaluation/results_sub/test_cog/2025-08-07T12:09:39-Qwen3-4B/test_cog_output_extracted.parquet"

ans_path = '/projectnb/vkolagrp/bellitti/adrd-foundation-model/adrd_simplified_evaluation/results_sub/test_cog/2025-08-07T14:26:00-Qwen2.5-7B-Instruct/test_cog_output_extracted.parquet'

ans = pd.read_parquet(ans_path)

# %%
ans[ans['extracted'] == 'invalid'][['generated_text','ground_truth','ground_truth_text','extracted','prediction']]
# Out:
#                                         generated_text ground_truth  \
# 0    To determine the correct cognitive status for ...            A
# 2    To determine the patient's cognitive status, w...            C
# 5    Let's analyze the data step by step to determi...            B
# 32   To classify the patient's cognitive status, le...            B
# 34   Let's analyze the patient's information step-b...            B
# 40   To determine the patient's cognitive status ba...            C
# 56   Let's go through the information provided step...            C
# 67   To determine the cognitive status of the patie...            B
# 75   To determine the patient's cognitive status, w...            B
# 80   To determine the correct cognitive status for ...            A
# 85   To determine the patient's cognitive status, l...            A
# 106  Let's analyze the patient's information step-b...            A
# 112  To analyze the patient's cognitive status, we ...            A
# 113  To determine the patient's cognitive status, w...            A
# 115  To determine the patient's cognitive status, l...            A
# 126  Let's analyze the information step by step to ...            B
# 154  To classify the patient's cognitive status, le...            A
# 166  To determine the cognitive status of the patie...            A
# 170  To determine the patient's cognitive status ba...            C
# 189  To analyze the patient's cognitive status, we ...            B
# 194  Let's reason through the details provided in t...            B
#
#                    ground_truth_text extracted prediction
# 0                      Dementia (DE)   invalid          A
# 2                      Dementia (DE)   invalid          B
# 5                      Dementia (DE)   invalid          B
# 32                     Dementia (DE)   invalid          B
# 34                     Dementia (DE)   invalid          C
# 40   Mild Cognitive Impairment (MCI)   invalid          B
# 56                     Dementia (DE)   invalid          A
# 67                     Dementia (DE)   invalid          B
# 75                     Dementia (DE)   invalid          B
# 80   Mild Cognitive Impairment (MCI)   invalid          B
# 85                     Dementia (DE)   invalid          A
# 106                    Dementia (DE)   invalid          B
# 112                    Dementia (DE)   invalid          A
# 113                    Dementia (DE)   invalid          A
# 115                    Dementia (DE)   invalid          A
# 126                    Dementia (DE)   invalid          B
# 154                    Dementia (DE)   invalid          A
# 166                    Dementia (DE)   invalid          A
# 170                    Dementia (DE)   invalid          A
# 189                    Dementia (DE)   invalid          B
# 194                    Dementia (DE)   invalid          B

# %%
print(ans.loc[126,'generated_text'])
# Out:
# Let's analyze the information step by step to determine the patient's cognitive status.
#
# 1. **Demographics and Education Level:**
#    - The subject is 61 years old and has completed 16 years of education. Educational level can sometimes influence cognitive assessment, but it is not the determining factor here as all other signs are more indicative.
#
# 2. **Health History and Medication:**
#    - He has a recent or active parkinsonian disorder, highlighting neurological involvement.
#    - He also has a history of traumatic brain injury (though remote and without chronic deficits), though its impact is less evident now.
#    - He is currently taking medications: levetiracetam (anticonvulsant), galantamine (acetylcholine esterase inhibitor for mild to moderate Alzheimer's disease), and memantine (NMDA antagonist for moderate to severe Alzheimer's disease).
#    - Depressive episodes and recent depressive symptoms suggest a mental health issue which can affect cognitive function but is more a mood disorder than a primary cognitive issue.
#
# 3. **Neuropsychiatric Inventory Questionnaire (NPI-Q):**
#    - The patient shows moderate apathy and severe appetite and eating problems.
#    - He also exhibits mild depression, mild anxiety, and a motor disturbance (suggesting possible parkinsonian symptoms).
#    - Other issues such as delusions, hallucinations, agitation, irritability, etc., are not present.
#
# 4. **Functional Assessment Scale (FAS):**
#    - The subject is completely dependent on assistance for managing finances, shopping, engaging in recreational or skill-based activities, preparing meals, keeping track of events, understanding media or reading materials, remembering appointments or medications, and traveling outside the neighborhood.
#    - This indicates significant dependence that is not explained solely by parkinsonism, as he can still perform basic daily tasks with assistance.
#
# 5. **Genetic Information:**
#    - His APOE genotype is (e3 e4), indicating one copy of the e4 allele, which is a known risk factor for late-onset Alzheimer's disease.
#
# Combining all these factors, the patient shows functional impairments across a wide range of daily activities that go beyond normal aging or medication effects. The motor disturbances, apathy, cognitive difficulties in understanding media, remembering appointments, and more, indicate significant functional decline, suggesting a more severe cognitive impairment rather than mild cognitive impairment (MCI).
#
# Given these points, the most fitting diagnosis is Dementia (DE) among the given options.
#
# Therefore, the correct cognitive status for the patient is \boxed{Dementia (DE)}.

# %%
ans[['ID','finish_reason','ground_truth','extracted']]
# Out:
#              ID finish_reason ground_truth extracted
# 0    NACC205850          stop            A         A
# 1    NACC205850          stop            A         A
# 2    NACC535610          stop            C         C
# 3    NACC535610          stop            C         C
# 4    NACC128740          stop            B         A
# ..          ...           ...          ...       ...
# 195  NACC495249          stop            B         B
# 196  NACC212495          stop            C         B
# 197  NACC212495          stop            C         C
# 198  NACC853578          stop            A         A
# 199  NACC853578          stop            A         A
#
# [200 rows x 4 columns]

# %%
mask = ans["extracted"] == "invalid"

ans["extracted_reprocessed"] = ans["extracted"]

ans.loc[mask, "extracted_reprocessed"] = ans.loc[mask, ["extracted","options"]].apply(
    lambda row: row["extracted"] + row["options"],
    axis=1,  # applies the function to each row
)
